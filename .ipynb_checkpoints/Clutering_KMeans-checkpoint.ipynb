# %%
# Imports ======================================================================================================================
import pandas as pd
import matplotlib.pyplot as plt

from sklearnex import patch_sklearn
patch_sklearn()
from sklearn.preprocessing import StandardScaler
from IPython.display import display, HTML
from sklearn.cluster import KMeans
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# Data reading =================================================================================================================
dfo = pd.read_csv('/Users/Luis1/Projetos/Python/estudo/anomaly_detection/datasets/csv/btc_orderbook_df.csv')
dft = pd.read_csv('/Users/Luis1/Projetos/Python/estudo/anomaly_detection/datasets/csv/btc_trades_df.csv')
dfo.columns = ['price', 'volume', 'type']
dft.columns = ['date','type','price', 'volume']

def display_side_by_side(dfs:list, captions:list, tablespacing=5):
    output = ""
    for (caption, df) in zip(captions, dfs):
        output += df.style.set_table_attributes("style='display:inline'").set_caption(caption)._repr_html_()
        output += tablespacing * "\xa0"
    display(HTML(output))
    
display_side_by_side([dfo.head(10), dft.head(10)], ['OrderBook', 'Trade'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Data reading =================================================================================================================
# ----> 2 dfo = pd.read_csv('/Users/Luis1/Projetos/Detection/datasets/csv/btc_orderbook_df.csv')
#       3 dft = pd.read_csv('/Users/Luis1/Projetos/Detection/datasets/csv/btc_trades_df.csv')
#       4 dfo.columns = ['price', 'volume', 'type']
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Luis1/Projetos/Detection/datasets/csv/btc_orderbook_df.csv'

# %%
display_side_by_side([dfo.describe(), dft.describe()], ['OrderBook-Describe', 'Trade-Describe'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_efb4b" style='display:inline'>
#   <caption>OrderBook-Describe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efb4b_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_efb4b_level0_col1" class="col_heading level0 col1" >volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efb4b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_efb4b_row0_col0" class="data row0 col0" >2000.000000</td>
#       <td id="T_efb4b_row0_col1" class="data row0 col1" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_efb4b_row1_col0" class="data row1 col0" >189136.844558</td>
#       <td id="T_efb4b_row1_col1" class="data row1 col1" >0.035951</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_efb4b_row2_col0" class="data row2 col0" >64320.034241</td>
#       <td id="T_efb4b_row2_col1" class="data row2 col1" >0.164832</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_efb4b_row3_col0" class="data row3 col0" >20050.000000</td>
#       <td id="T_efb4b_row3_col1" class="data row3 col1" >0.000004</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_efb4b_row4_col0" class="data row4 col0" >151260.740000</td>
#       <td id="T_efb4b_row4_col1" class="data row4 col1" >0.000014</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_efb4b_row5_col0" class="data row5 col0" >207100.000000</td>
#       <td id="T_efb4b_row5_col1" class="data row5 col1" >0.000615</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_efb4b_row6_col0" class="data row6 col0" >239513.114785</td>
#       <td id="T_efb4b_row6_col1" class="data row6 col1" >0.005940</td>
#     </tr>
#     <tr>
#       <th id="T_efb4b_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_efb4b_row7_col0" class="data row7 col0" >270199.999900</td>
#       <td id="T_efb4b_row7_col1" class="data row7 col1" >2.626832</td>
#     </tr>
#   </tbody>
# </table>
#      <style type="text/css">
# </style>
# <table id="T_e9d6f" style='display:inline'>
#   <caption>Trade-Describe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9d6f_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_e9d6f_level0_col1" class="col_heading level0 col1" >price</th>
#       <th id="T_e9d6f_level0_col2" class="col_heading level0 col2" >volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9d6f_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e9d6f_row0_col0" class="data row0 col0" >264000.000000</td>
#       <td id="T_e9d6f_row0_col1" class="data row0 col1" >264000.000000</td>
#       <td id="T_e9d6f_row0_col2" class="data row0 col2" >264000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_e9d6f_row1_col0" class="data row1 col0" >1699650457.328902</td>
#       <td id="T_e9d6f_row1_col1" class="data row1 col1" >178397.061304</td>
#       <td id="T_e9d6f_row1_col2" class="data row1 col2" >0.009541</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_e9d6f_row2_col0" class="data row2 col0" >1794284.078972</td>
#       <td id="T_e9d6f_row2_col1" class="data row2 col1" >23230.389949</td>
#       <td id="T_e9d6f_row2_col2" class="data row2 col2" >0.037683</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_e9d6f_row3_col0" class="data row3 col0" >1696007008.000000</td>
#       <td id="T_e9d6f_row3_col1" class="data row3 col1" >134641.340000</td>
#       <td id="T_e9d6f_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_e9d6f_row4_col0" class="data row4 col0" >1698148293.000000</td>
#       <td id="T_e9d6f_row4_col1" class="data row4 col1" >169600.000100</td>
#       <td id="T_e9d6f_row4_col2" class="data row4 col2" >0.000136</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_e9d6f_row5_col0" class="data row5 col0" >1699642121.000000</td>
#       <td id="T_e9d6f_row5_col1" class="data row5 col1" >178436.935239</td>
#       <td id="T_e9d6f_row5_col2" class="data row5 col2" >0.000600</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_e9d6f_row6_col0" class="data row6 col0" >1701361593.000000</td>
#       <td id="T_e9d6f_row6_col1" class="data row6 col1" >187395.943871</td>
#       <td id="T_e9d6f_row6_col2" class="data row6 col2" >0.004800</td>
#     </tr>
#     <tr>
#       <th id="T_e9d6f_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_e9d6f_row7_col0" class="data row7 col0" >1702340105.000000</td>
#       <td id="T_e9d6f_row7_col1" class="data row7 col1" >221578.350000</td>
#       <td id="T_e9d6f_row7_col2" class="data row7 col2" >3.200104</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data standardization =========================================================================================================
scaler = StandardScaler()
anomaly_inputs = ['price', 'volume']
dfo[['price_T','volume_T']] = scaler.fit_transform(dfo[anomaly_inputs])
dft[['price_T','volume_T']] = scaler.fit_transform(dft[anomaly_inputs])
display_side_by_side([dfo.head(10), dft.head(10)], ['OrderBook-Standard', 'Trade-Standard'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ffcb" style='display:inline'>
#   <caption>OrderBook-Standard</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ffcb_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_6ffcb_level0_col1" class="col_heading level0 col1" >volume</th>
#       <th id="T_6ffcb_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_6ffcb_level0_col3" class="col_heading level0 col3" >price_T</th>
#       <th id="T_6ffcb_level0_col4" class="col_heading level0 col4" >volume_T</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ffcb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ffcb_row0_col0" class="data row0 col0" >207100.000000</td>
#       <td id="T_6ffcb_row0_col1" class="data row0 col1" >0.022100</td>
#       <td id="T_6ffcb_row0_col2" class="data row0 col2" >sell</td>
#       <td id="T_6ffcb_row0_col3" class="data row0 col3" >0.279348</td>
#       <td id="T_6ffcb_row0_col4" class="data row0 col4" >-0.084053</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ffcb_row1_col0" class="data row1 col0" >207165.000000</td>
#       <td id="T_6ffcb_row1_col1" class="data row1 col1" >0.328000</td>
#       <td id="T_6ffcb_row1_col2" class="data row1 col2" >sell</td>
#       <td id="T_6ffcb_row1_col3" class="data row1 col3" >0.280358</td>
#       <td id="T_6ffcb_row1_col4" class="data row1 col4" >1.772245</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ffcb_row2_col0" class="data row2 col0" >207273.000000</td>
#       <td id="T_6ffcb_row2_col1" class="data row2 col1" >0.328000</td>
#       <td id="T_6ffcb_row2_col2" class="data row2 col2" >sell</td>
#       <td id="T_6ffcb_row2_col3" class="data row2 col3" >0.282038</td>
#       <td id="T_6ffcb_row2_col4" class="data row2 col4" >1.772245</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ffcb_row3_col0" class="data row3 col0" >207352.000000</td>
#       <td id="T_6ffcb_row3_col1" class="data row3 col1" >0.499000</td>
#       <td id="T_6ffcb_row3_col2" class="data row3 col2" >sell</td>
#       <td id="T_6ffcb_row3_col3" class="data row3 col3" >0.283266</td>
#       <td id="T_6ffcb_row3_col4" class="data row3 col4" >2.809926</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ffcb_row4_col0" class="data row4 col0" >207550.990000</td>
#       <td id="T_6ffcb_row4_col1" class="data row4 col1" >0.017000</td>
#       <td id="T_6ffcb_row4_col2" class="data row4 col2" >sell</td>
#       <td id="T_6ffcb_row4_col3" class="data row4 col3" >0.286361</td>
#       <td id="T_6ffcb_row4_col4" class="data row4 col4" >-0.115001</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ffcb_row5_col0" class="data row5 col0" >207634.976903</td>
#       <td id="T_6ffcb_row5_col1" class="data row5 col1" >0.566024</td>
#       <td id="T_6ffcb_row5_col2" class="data row5 col2" >sell</td>
#       <td id="T_6ffcb_row5_col3" class="data row5 col3" >0.287667</td>
#       <td id="T_6ffcb_row5_col4" class="data row5 col4" >3.216651</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ffcb_row6_col0" class="data row6 col0" >207634.982241</td>
#       <td id="T_6ffcb_row6_col1" class="data row6 col1" >0.566024</td>
#       <td id="T_6ffcb_row6_col2" class="data row6 col2" >sell</td>
#       <td id="T_6ffcb_row6_col3" class="data row6 col3" >0.287667</td>
#       <td id="T_6ffcb_row6_col4" class="data row6 col4" >3.216651</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ffcb_row7_col0" class="data row7 col0" >207634.987570</td>
#       <td id="T_6ffcb_row7_col1" class="data row7 col1" >0.245000</td>
#       <td id="T_6ffcb_row7_col2" class="data row7 col2" >sell</td>
#       <td id="T_6ffcb_row7_col3" class="data row7 col3" >0.287667</td>
#       <td id="T_6ffcb_row7_col4" class="data row7 col4" >1.268574</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ffcb_row8_col0" class="data row8 col0" >207638.330000</td>
#       <td id="T_6ffcb_row8_col1" class="data row8 col1" >0.183000</td>
#       <td id="T_6ffcb_row8_col2" class="data row8 col2" >sell</td>
#       <td id="T_6ffcb_row8_col3" class="data row8 col3" >0.287719</td>
#       <td id="T_6ffcb_row8_col4" class="data row8 col4" >0.892339</td>
#     </tr>
#     <tr>
#       <th id="T_6ffcb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ffcb_row9_col0" class="data row9 col0" >207638.340000</td>
#       <td id="T_6ffcb_row9_col1" class="data row9 col1" >0.000010</td>
#       <td id="T_6ffcb_row9_col2" class="data row9 col2" >sell</td>
#       <td id="T_6ffcb_row9_col3" class="data row9 col3" >0.287719</td>
#       <td id="T_6ffcb_row9_col4" class="data row9 col4" >-0.218102</td>
#     </tr>
#   </tbody>
# </table>
#      <style type="text/css">
# </style>
# <table id="T_eb5d5" style='display:inline'>
#   <caption>Trade-Standard</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb5d5_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_eb5d5_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_eb5d5_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_eb5d5_level0_col3" class="col_heading level0 col3" >volume</th>
#       <th id="T_eb5d5_level0_col4" class="col_heading level0 col4" >price_T</th>
#       <th id="T_eb5d5_level0_col5" class="col_heading level0 col5" >volume_T</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb5d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb5d5_row0_col0" class="data row0 col0" >1696007008</td>
#       <td id="T_eb5d5_row0_col1" class="data row0 col1" >buy</td>
#       <td id="T_eb5d5_row0_col2" class="data row0 col2" >135078.450000</td>
#       <td id="T_eb5d5_row0_col3" class="data row0 col3" >0.015500</td>
#       <td id="T_eb5d5_row0_col4" class="data row0 col4" >-1.864742</td>
#       <td id="T_eb5d5_row0_col5" class="data row0 col5" >0.158142</td>
#     </tr>
#     <tr>
#       <th id="T_eb5d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb5d5_row1_col0" class="data row1 col0" >1696007008</td>
#       <td id="T_eb5d5_row1_col1" class="data row1 col1" >buy</td>
#       <td id="T_eb5d5_row1_col2" class="data row1 col2" >135078.450000</td>
#       <td id="T_eb5d5_row1_col3" class="data row1 col3" >0.044400</td>
#       <td id="T_eb5d5_row1_col4" class="data row1 col4" >-1.864742</td>
#       <td id="T_eb5d5_row1_col5" class="data row1 col5" >0.925067</td>
#     </tr>
#     <tr>
#       <th id="T_eb5d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb5d5_row2_col0" class="data row2 col0" >1696007008</td>
#       <td id="T_eb5d5_row2_col1" class="data row2 col1" >buy</td>
#       <td id="T_eb5d5_row2_col2" class="data row2 col2" >135083.000000</td>
#       <td id="T_eb5d5_row2_col3" class="data row2 col3" >0.159676</td>
#       <td id="T_eb5d5_row2_col4" class="data row2 col4" >-1.864547</td>
#       <td id="T_eb5d5_row2_col5" class="data row2 col5" >3.984170</td>
#     </tr>
#     <tr>
#       <th id="T_eb5d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb5d5_row3_col0" class="data row3 col0" >1696007012</td>
#       <td id="T_eb5d5_row3_col1" class="data row3 col1" >buy</td>
#       <td id="T_eb5d5_row3_col2" class="data row3 col2" >135083.000000</td>
#       <td id="T_eb5d5_row3_col3" class="data row3 col3" >0.068600</td>
#       <td id="T_eb5d5_row3_col4" class="data row3 col4" >-1.864547</td>
#       <td id="T_eb5d5_row3_col5" class="data row3 col5" >1.567267</td>
#     </tr>
#     <tr>
#       <th id="T_eb5d5_level0_row4" class="row_heading level0 row4" >4</th>

# %%
# Graphical analysis for cluster optimization ==================================================================================
def  optimise_k_means(data, max_k):
    means = []
    inertias = []
    
    for k in range(1, max_k):
        kmeans = KMeans(n_clusters=k,n_init='auto')
        kmeans.fit(data)
        
        means.append(k)
        inertias.append(kmeans.inertia_)
        
        fig = plt.subplots(figsize=(10,5))
        plt.plot(means, inertias, 'o-')
        plt.xlabel('Numero de clusters')
        plt.ylabel('Inercia')
        plt.grid(True)
        plt.show()

# %%
optimise_k_means(dfo[['price_T','volume_T']], 10)

# %%
optimise_k_means(dft[['price_T','amount_T']], 10)

# %%
# Cluster creation =============================================================================================================
kmeansO = KMeans(n_clusters=4,n_init='auto')
kmeansO.fit(dfo[['price_T','volume_T']])
# Out:
# KMeans(n_clusters=4, n_init='auto')

# %%
dfo['kmeans_4'] = kmeansO.labels_
dfo.head(5)
# Out:
#        price  volume  type   price_T  volume_T  kmeans_4
# 0  207100.00  0.0221  sell  0.279348 -0.084053         1
# 1  207165.00  0.3280  sell  0.280358  1.772245         0
# 2  207273.00  0.3280  sell  0.282038  1.772245         0
# 3  207352.00  0.4990  sell  0.283266  2.809926         0
# 4  207550.99  0.0170  sell  0.286361 -0.115001         1

# %%
kmeansT = KMeans(n_clusters=6,n_init='auto')
kmeansT.fit(dft[['price_T','volume_T']])
# Out:
# KMeans(n_clusters=6, n_init='auto')

# %%
dft['kmeans_6'] = kmeansT.labels_
dft.head(5)
# Out:
#          date type      price    volume   price_T  volume_T  kmeans_6
# 0  1696007008  buy  135078.45  0.015500 -1.864742  0.158142         3
# 1  1696007008  buy  135078.45  0.044400 -1.864742  0.925067         3
# 2  1696007008  buy  135083.00  0.159676 -1.864547  3.984170         4
# 3  1696007012  buy  135083.00  0.068600 -1.864547  1.567267         3
# 4  1696007048  buy  135187.00  0.000148 -1.860070 -0.249259         3

# %%
plt.scatter(x=dfo['price'], y=dfo['volume'], c=dfo['kmeans_4'])
plt.xlim(10000.00,280000.00)
plt.ylim(-0.2,4)
plt.xlabel('price')
plt.ylabel('volume')
plt.title("OrderBook Cluster")
plt.show()

plt.scatter(x=dft['price'], y=dft['volume'], c=dft['kmeans_6'])
plt.xlim(130000.00,230000.00)
plt.ylim(-0.2,3.5)
plt.xlabel('price')
plt.ylabel('amount')
plt.title("Trade Cluster")
plt.show()

# %%
for k in range(1,5):
    kmeans = KMeans(n_clusters=k,n_init='auto')
    kmeans.fit(dfo[['price_T','volume_T']])
    dfo[f'KMeans_{k}'] = kmeans.labels_
dfo.head(5)
# Out:
#        price  volume  type   price_T  volume_T  kmeans_4  KMeans_1  KMeans_2  \
# 0  207100.00  0.0221  sell  0.279348 -0.084053         1         0         0
# 1  207165.00  0.3280  sell  0.280358  1.772245         0         0         0
# 2  207273.00  0.3280  sell  0.282038  1.772245         0         0         0
# 3  207352.00  0.4990  sell  0.283266  2.809926         0         0         0
# 4  207550.99  0.0170  sell  0.286361 -0.115001         1         0         0
#
#    KMeans_3  KMeans_4
# 0         0         3
# 1         0         3
# 2         0         3
# 3         0         3
# 4         0         3

# %%
for k in range(1,7):
    kmeans = KMeans(n_clusters=k,n_init='auto')
    kmeans.fit(dft[['price_T','volume_T']])
    dft[f'KMeans_{k}'] = kmeans.labels_
dft.head(5)

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(30,5))

for i, ax in enumerate(fig.axes, start=1):
    ax.scatter(x=dfo['price'], y=dfo['volume'], c=dfo[f'KMeans_{i}'])
    ax.set_title(f'N Clusters: {i}')
plt.savefig('./graph/frame.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(30,5))
#       3 for i, ax in enumerate(fig.axes, start=1):
#       4     ax.scatter(x=dfo['price'], y=dfo['volume'], c=dfo[f'KMeans_{i}'])
#
# NameError: name 'plt' is not defined

# %%
animated_plot = plt.scatter(x=dfo['price'], y=dfo['volume'], c=dfo['kmeans_4'])

def update(i):
    # for ax, k in zip(axs, range(1, 5)):
    #     ax.clear()
    #     ax.scatter(x=dfo['price'], y=dfo['volume'], c=dfo[f'KMeans_{k}'])
        # ax.set_title(f'N Clusters: {k}')

    return animated_plot
        
# Crie a animação
ani = animation.FuncAnimation(fig, update, frames=range(100), interval=100)

# Salve o GIF
ani.save('teste.gif', writer='imagemagick')
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.

# %%
fig, axs = plt.subplots(nrows=1, ncols=6, figsize=(30,5))

for i, ax in enumerate(fig.axes, start=1):
    ax.scatter(x=dft['price'], y=dft['amount'], c=dft[f'KMeans_{i}'])
    ax.set_xlim(130000.00,230000.00)
    ax.set_ylim(-0.2,3.5)
    ax.set_title(f'N Clusters: {i}')
