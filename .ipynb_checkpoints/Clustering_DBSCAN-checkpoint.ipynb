# %%
# Imports ======================================================================================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
# Data reading =================================================================================================================
dfo = pd.read_csv('/Users/Luis1/Projetos/Detection/datasets/csv/btc_orderbook_df.csv')
dft = pd.read_csv('/Users/Luis1/Projetos/Detection/datasets/csv/btc_trades_df.csv')
dfo.head(5), dft.head(5)
# Out:
# (       price  volume  type
#  0  207100.00  0.0221  sell
#  1  207165.00  0.3280  sell
#  2  207273.00  0.3280  sell
#  3  207352.00  0.4990  sell
#  4  207550.99  0.0170  sell,
#           date type      price    amount
#  0  1696007008  buy  135078.45  0.015500
#  1  1696007008  buy  135078.45  0.044400
#  2  1696007008  buy  135083.00  0.159676
#  3  1696007012  buy  135083.00  0.068600
#  4  1696007048  buy  135187.00  0.000148)

# %%
# Data standardization =========================================================================================================
scaler = StandardScaler()
dfo[['price_T','volume_T']] = scaler.fit_transform(dfo[['price','volume']])
dft[['price_T','amount_T']] = scaler.fit_transform(dft[['price','amount']])
dfo.head(5), dft.head(5)
# Out:
# (       price  volume  type   price_T  volume_T
#  0  207100.00  0.0221  sell  0.279348 -0.084053
#  1  207165.00  0.3280  sell  0.280358  1.772245
#  2  207273.00  0.3280  sell  0.282038  1.772245
#  3  207352.00  0.4990  sell  0.283266  2.809926
#  4  207550.99  0.0170  sell  0.286361 -0.115001,
#           date type      price    amount   price_T  amount_T
#  0  1696007008  buy  135078.45  0.015500 -1.864742  0.158142
#  1  1696007008  buy  135078.45  0.044400 -1.864742  0.925067
#  2  1696007008  buy  135083.00  0.159676 -1.864547  3.984170
#  3  1696007012  buy  135083.00  0.068600 -1.864547  1.567267
#  4  1696007048  buy  135187.00  0.000148 -1.860070 -0.249259)

# %%
dbscanO = DBSCAN(eps=0.5, min_samples = 12, metric='euclidean', algorithm='ball_tree', leaf_size=30)
dbscanO.fit(dfo[['price_T','volume_T']])
dfo['dbscan'] = dbscanO.labels_
dfo
# Out:
#           price    volume  type   price_T  volume_T  dbscan
# 0     207100.00  0.022100  sell  0.279348 -0.084053       0
# 1     207165.00  0.328000  sell  0.280358  1.772245       0
# 2     207273.00  0.328000  sell  0.282038  1.772245       0
# 3     207352.00  0.499000  sell  0.283266  2.809926      -1
# 4     207550.99  0.017000  sell  0.286361 -0.115001       0
# ...         ...       ...   ...       ...       ...     ...
# 1995   20940.00  0.001008   buy -2.615653 -0.212045       0
# 1996   20600.00  0.000022   buy -2.620941 -0.218028       0
# 1997   20574.71  0.068247   buy -2.621334  0.195981       0
# 1998   20416.01  0.000070   buy -2.623802 -0.217738       0
# 1999   20050.00  0.002547   buy -2.629494 -0.202706       0
#
# [2000 rows x 6 columns]

# %%
dbscanT = DBSCAN(eps=0.1, min_samples = 12, metric='euclidean')
dbscanT.fit(dft[['price_T','amount_T']])
dft['dbscan'] = dbscanT.labels_
dft

# %%
outliers_dfo = dfo[dfo.dbscan == -1]
clusters_dfo = dfo[dfo.dbscan != -1]

colors = dbscanO.labels_
color_clusters = colors[colors != -1]
color_outliers = 'red'

clusters = Counter(dbscanO.labels_)

# %%
fig = plt.figure()
ax = fig.add_axes([.1, .1, 1, 1])
ax.scatter(x=clusters_dfo['price'], y=clusters_dfo['volume'], c=color_clusters, edgecolor='black', s=50)
ax.scatter(x=outliers_dfo['price'], y=outliers_dfo['volume'], c=color_outliers, edgecolor='black',s=50)

ax.set_xlabel('price', family='Arial', fontsize=9)
ax.set_ylabel('volume', family='Arial', fontsize=9)

plt.title('OrderBook Cluster', family='Arial', fontsize=12)
plt.grid(which='major', color='#cccccc', alpha=0.45)
plt.show()

print(clusters)
print(dfo[dfo.dbscan == -1].head())
print('Number of clusters = {}'.format(len(clusters)-1))
# Out:
# Counter({0: 1947, -1: 53})
#             price    volume  type   price_T  volume_T  dbscan
# 3   207352.000000  0.499000  sell  0.283266  2.809926      -1
# 5   207634.976903  0.566024  sell  0.287667  3.216651      -1
# 6   207634.982241  0.566024  sell  0.287667  3.216651      -1
# 51  208468.000000  1.668000  sell  0.300622  9.903787      -1
# 54  209533.000000  1.012000  sell  0.317184  5.922972      -1
# Number of clusters = 1
